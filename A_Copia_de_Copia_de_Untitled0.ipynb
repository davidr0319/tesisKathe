# %% [markdown]
# <a href="https://colab.research.google.com/github/davidr0319/tesisKathe/blob/main/A_Copia_de_Copia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nivel de enfermedad pulmonar crónica del paciente

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importando conjunto de datos
import pandas as pd
import numpy as np

#Cargando datos pima indians dataset
data = pd.read_excel(r"/content/drive/MyDrive/final/TRABAJO FINAL/A cancer patient data sets.xlsx")
data.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %%
# Quito campos indeseados
data=data.drop(columns=["index","Patient Id","Age"],axis=1)
#resumen de los datos
data.head()
# Out:
#    Gender  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0       1              2            4             5                     4
# 1       1              3            1             5                     3
# 2       1              4            5             6                     5
# 3       1              7            7             7                     7
# 4       1              6            8             7                     7
#
#    Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  ...  \
# 0             3                     2              2        4        3  ...
# 1             4                     2              2        2        2  ...
# 2             5                     4              6        7        2  ...
# 3             6                     7              7        7        7  ...
# 4             7                     6              7        7        8  ...
#
# ...

# %%
data.describe()
# Out:
#             Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  1000.000000      1000.0000  1000.000000   1000.000000
# mean      1.402000         3.8400     4.563000      5.165000
# std       0.490547         2.0304     2.620477      1.980833
# min       1.000000         1.0000     1.000000      1.000000
# 25%       1.000000         2.0000     2.000000      4.000000
# 50%       1.000000         3.0000     5.000000      6.000000
# 75%       2.000000         6.0000     7.000000      7.000000
# max       2.000000         8.0000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count           1000.000000   1000.000000           1000.000000
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# min                1.000000      1.000000              1.000000
# 25%                3.000000      2.000000              3.000000
# ...

# %%
# Ajusto valores de etiquetas
Salida_Strategy={"Low":1,"High":2}
data["Level"]=data["Level"].map(Salida_Strategy)

#resumen de los datos
data.head()
# Out:
#    Gender  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0       1              2            4             5                     4
# 1       1              3            1             5                     3
# 2       1              4            5             6                     5
# 3       1              7            7             7                     7
# 4       1              6            8             7                     7
#
#    Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  ...  \
# 0             3                     2              2        4        3  ...
# 1             4                     2              2        2        2  ...
# 2             5                     4              6        7        2  ...
# 3             6                     7              7        7        7  ...
# 4             7                     6              7        7        8  ...
#
# ...

# %%
# Dividir el conjunto de datos en variables de entrada (X) y salida (Y)
Datos=np.array(data)
X = Datos[:,0:22] #Entrada
Y = Datos[:,22] #Salida
print(X.shape,Y.shape)
# Out:
# (1000, 22) (1000,)

# %%
#3. Divida la entrada y la salida en conjuntos de entrenamiento y prueba
import sklearn
from sklearn.model_selection import train_test_split
X_train, X_test,Y_train, Y_test= train_test_split(X,Y,test_size=0.1)
print(X_train.shape,X_test.shape )
# Out:
# (900, 22) (100, 22)

# %% [markdown]
# =========================Vecinos más cercanos==============================

# %%
#4. Evaluando casos mediante VECINOS
from sklearn.neighbors import KNeighborsClassifier
pronostico_0 = KNeighborsClassifier(5) #
pronostico_0.fit(X_train,Y_train)
Y_pred_0 =pronostico_0.predict (X_test)
# calculando desempeño (Exactitud)
from sklearn.metrics import accuracy_score,precision_score
print("Accuracy ",accuracy_score(Y_test, Y_pred_0))
# Out:
# Accuracy  1.0

# %%
#Guardando el pronostico entrenado
import joblib
joblib.dump(pronostico_0, "/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_VECINOS.joblib")
# Out:
# ['/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_VECINOS.joblib']

# %% [markdown]
# =========================Bayes==============================

# %%
#5. Evaluando casos mediante Naive Bayes
from sklearn.naive_bayes import GaussianNB
pronostico_1 = GaussianNB()
pronostico_1.fit(X_train, Y_train)
Y_pred =pronostico_1.predict (X_test)
from sklearn.metrics import accuracy_score,precision_score
print("Accuracy ",accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy  0.89

# %%
#Guardando el pronostico entrenado
import joblib
joblib.dump(pronostico_1, "/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_Bayes.joblib")
# Out:
# ['/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_Bayes.joblib']

# %% [markdown]
# ======================LDA=================================

# %%
#6. Evaluando casos mediante LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
pronostico_2 = LinearDiscriminantAnalysis()
pronostico_2.fit(X_train, Y_train)
Y_pred_2 =pronostico_2.predict (X_test)
from sklearn.metrics import accuracy_score,precision_score
print("Accuracy ",accuracy_score(Y_test, Y_pred_2))
# Out:
# Accuracy  0.96

# %%
#Guardando el pronostico entrenado LDA
import joblib
joblib.dump(pronostico_2, "/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_LDA.joblib")
# Out:
# ['/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_LDA.joblib']

# %% [markdown]
# ==========================QDA==================================

# %%
#8. Evaluando casos mediante QDA
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
pronostico_3 = QuadraticDiscriminantAnalysis()
pronostico_3.fit(X_train, Y_train)
Y_pred_3 =pronostico_3.predict (X_test)
from sklearn.metrics import accuracy_score,precision_score
print("Accuracy ",accuracy_score(Y_test, Y_pred_3))
# Out:
# Accuracy  1.0

# %%
#Guardando el pronostico entrenado
import joblib
joblib.dump(pronostico_3, "/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_QDA.joblib")
# Out:
# ['/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_QDA.joblib']

# %% [markdown]
# =============================Tree===============================

# %%
#9. Evaluando casos mediante Tree 
from sklearn.tree import DecisionTreeClassifier
pronostico_4 = DecisionTreeClassifier()
pronostico_4.fit(X_train, Y_train)
Y_pred_4 =pronostico_4.predict (X_test)
from sklearn.metrics import accuracy_score,precision_score
print("Accuracy ",accuracy_score(Y_test, Y_pred_4))
# Out:
# Accuracy  1.0

# %%
#Guardando el pronostico entrenado
import joblib
joblib.dump(pronostico_4, "/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_TREE.joblib")
# Out:
# ['/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_TREE.joblib']

# %% [markdown]
# ==================================SVM==================================

# %%
#10.Evaluando casos mediante Tree  SVM 
from sklearn.svm import SVC
pronostico_5 = SVC()
pronostico_5.fit(X_train, Y_train)
Y_pred_5 =pronostico_5.predict (X_test)
from sklearn.metrics import accuracy_score,precision_score
print("Accuracy ",accuracy_score(Y_test, Y_pred_5))
# Out:
# Accuracy  1.0

# %%
#Guardando el pronostico entrenado
import joblib
joblib.dump(pronostico_5, "/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_SVM.joblib")
# Out:
# ['/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_SVM.joblib']

# %% [markdown]
# NUEVO CODIGO B CREANDO NUEVO PASCIENTE

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importando dataset.
import pandas as pd
import numpy as np

#Cargando datos pima indians dataset
data = pd.read_excel(r"/content/drive/MyDrive/final/TRABAJO FINAL/A cancer patient data sets.xlsx")
data.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %%
#Cargando el pronostico entrenado en una faceta anterior
import joblib
import numpy as np

pronostico = joblib.load("/content/drive/MyDrive/final/TRABAJO FINAL/pronostico_SVM.joblib")

# %% [markdown]
# ===========Utilizando el pronostico para predecir un caso nuevo===================

# %%
# Cargando datos de un suario nuevo
X_new = np.zeros((1,22))
X_new[0,0]=int(input("Genero?: marque 0 para masculino, 2 para femenino, 3 para ninguno\n"))
X_new[0,1]=int(input("Está  expuesto a: marque 1 para Contaminaciòn del aire, 0 para no\n"))
X_new[0,2]=int(input("Consumo de alcohol?: marque 1 para Si, 0 para No\n"))
X_new[0,3]=int(input("Es alergico al polvo?: marque 1 para Si, 0 para No\n"))
X_new[0,4]=int(input("Riesgos Laborales?: marque 1 para Si, 0 para No\n"))
X_new[0,5]=int(input("Riesgos genético?: marque 1 para Si, 0 para No\n"))
X_new[0,6]=int(input("Padece enfermedad pulmonar crónica?: marque 1 para Si, 0 para No\n"))
X_new[0,7]=int(input("Tiene una dieta equilibrada?: marque 1 para Si, 0 para No\n"))
X_new[0,8]=int(input("Padece obesidad?: marque 1 para Si, 0 para No\n"))
X_new[0,9]=int(input("Está expuesto al tabaquismo?: marque 1 para Si, 0 para No\n"))
X_new[0,10]=int(input("Es fumador pasivo?: marque 1 para Si, 0 para No\n"))
X_new[0,11]=int(input("Siente dolor de pecho?: marque 1 para Si, 0 para No\n"))
X_new[0,12]=int(input("Presenta tos con sangre?: marque 1 para Si, 0 para No\n"))
X_new[0,13]=int(input("Siente fatiga?: marque 1 para Si, 0 para No\n"))
X_new[0,14]=int(input("Presenta pérdida de peso?: marque 1 para Si, 0 para No\n"))
X_new[0,15]=int(input("Presenta dificultad para respirar?: marque 1 para Si, 0 para No\n"))
X_new[0,16]=int(input("Presenta sibilancias?: marque 1 para Si, 0 para No\n"))
X_new[0,17]=int(input("Siente dificultad para tragar?: marque 1 para Si, 0 para No\n"))
X_new[0,18]=int(input("Presenta dedos en palillo de tambor?: marque 1 para Si, 0 para No\n"))
X_new[0,19]=int(input("Ha tenido resfriado frecuente?: marque 1 para Si, 0 para No\n"))
X_new[0,20]=int(input("Presenta tos seca?: marque 1 para Si, 0 para No\n"))
X_new[0,21]=int(input("Presenta ronquidos?: marque 1 para Si, 0 para No\n"))
# Out:
# Genero?: marque 0 para masculino, 2 para femenino, 3 para ninguno
# 0
# Está  expuesto a: marque 1 para Contaminaciòn del aire, 0 para no
# 0
# Consumo de alcohol?: marque 1 para Si, 0 para No
# 0
# Es alergico al polvo?: marque 1 para Si, 0 para No
# 0
# Riesgos Laborales?: marque 1 para Si, 0 para No
# 0
# Riesgos genético?: marque 1 para Si, 0 para No
# 0
# Padece enfermedad pulmonar crónica?: marque 1 para Si, 0 para No
# 0
# Tiene una dieta equilibrada?: marque 1 para Si, 0 para No
# 0
# Padece obesidad?: marque 1 para Si, 0 para No
# 0
# Está expuesto al tabaquismo?: marque 1 para Si, 0 para No
# 0
# Es fumador pasivo?: marque 1 para Si, 0 para No
# 0
# Siente dolor de pecho?: marque 1 para Si, 0 para No
# 0
# Presenta tos con sangre?: marque 1 para Si, 0 para No
# 0
# Siente fatiga?: marque 1 para Si, 0 para No
# 0
# Presenta pérdida de peso?: marque 1 para Si, 0 para No
# 0
# Presenta dificultad para respirar?: marque 1 para Si, 0 para No
# 0
# ...

# %%
#Realizando la predicción a partir del pronostico entrenado
prediction = pronostico.predict(X_new)
if prediction == 0:
  Diagnostico = "bajo"
else:
  Diagnostico = "alto"

print("El nivel de enfermedad pulmonar crónica del paciente,  es posiblemente: ",Diagnostico, ", esto con una probabilidad del 100%")
# Out:
# El nivel de enfermedad pulmonar crónica del paciente,  es posiblemente:  alto , esto con una probabilidad del 100%
